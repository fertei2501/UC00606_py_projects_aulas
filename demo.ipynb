# %%
lista = [] # cria uma lista vazia

# %%
lista.append(1) # adiciona no fim
lista.append(3)

# %%
lista
# Out:
# [1, 3]

# %%
lst = [1,2,3,4]

# %%
lst.insert(0, 99) #adiciona na posição indicada

# %%
lst
# Out:
# [99, 1, 2, 3, 4]

# %%
Lista = []
for i in range(10_000_000):
    Lista.append(i)

# %%
len(Lista)
# Out:
# 10000000
