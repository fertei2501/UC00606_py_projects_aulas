# %%
24 / 02 / 2026

var
op
com
var
condiçoes

#cmt

"""
cmt
multi
linha
"""

# %%
\ncmt\nmulti\nlinha\n

# %%
nome = "Gonçalo 3" # -> string

# %%
nome = "Gonçalo"  # criar uma var

# %%
nome
print(nome)
# Out:
# Gonçalo 3

# %%
idade2: int = 12
nome2: str = "Gonçalo"
altura2: float = 1.2
aprovado2: bool = True

# %%
print(idade2)
idade2 = "Dez"
# Out:
# Dez

# %%
print(idade2)
# Out:
# Dez
